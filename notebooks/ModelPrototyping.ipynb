# %%
'''
    Clone the repo !
'''
# !git clone https://github.com/atikul-islam-sajib/GoodPractise/DSTD.git

# %%
# %cd /Users/shahmuhammadraditrahman/Desktop/IrisClassifier/iris_classifier/
# Out:
# /Users/shahmuhammadraditrahman/Desktop/IrisClassifier/iris_classifier

# %%
# !python /Users/shahmuhammadraditrahman/Desktop/IrisClassifier/iris_classifier/command_line.py --dataset /Users/shahmuhammadraditrahman/Desktop/IrisClassifier/data/raw/IRIS.csv --split 0.20 --preprocessing

# %%
# !python iris_classifier/command_line.py --model --epochs 300 --lr 0.001 --display True
# Out:
# Epochs - 0/300
# [===========] train_loss:1.1144816875457764 - train_accuracy:0.125 - val_loss:1.083513617515564 - val_accuracy:0.35714285714285715
# Epochs - 1/300
# [===========] train_loss:1.0795092582702637 - train_accuracy:0.5 - val_loss:1.0456398725509644 - val_accuracy:0.7857142857142857
# Epochs - 2/300
# [===========] train_loss:1.0439692735671997 - train_accuracy:0.5 - val_loss:1.054633617401123 - val_accuracy:0.5714285714285714
# Epochs - 3/300
# [===========] train_loss:1.0728553533554077 - train_accuracy:0.5 - val_loss:1.0373045206069946 - val_accuracy:0.5714285714285714
# Epochs - 4/300
# [===========] train_loss:0.9661054611206055 - train_accuracy:0.75 - val_loss:0.9694128036499023 - val_accuracy:0.7142857142857143
# Epochs - 5/300
# [===========] train_loss:0.9306309819221497 - train_accuracy:0.75 - val_loss:0.9477476477622986 - val_accuracy:0.6428571428571429
# Epochs - 6/300
# ...

# %%
# !python iris_classifier/command_line.py --predict
# Out:
# ACCURACY # 0.9666666666666667
# PRECISION # 0.9666666666666667
# RECALL # 0.9761904761904763
# F1_SCORE # 0.9701104613385315
